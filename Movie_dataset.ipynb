# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/IMDb Movies India.csv', encoding='latin-1')

# %% [markdown]
# Top 10 rows of dataset

# %%
data.head(10)
# Out:
#                                  Name    Year Duration  \
# 0                                         NaN      NaN
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 2                         #Homecoming  (2021)   90 min
# 3                             #Yaaram  (2019)  110 min
# 4                   ...And Once Again  (2010)  105 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 7                      .in for Motion  (2008)   59 min
# 8                  ?: A Question Mark  (2012)   82 min
# 9                            @Andheri  (2014)  116 min
#
#                        Genre  Rating  Votes            Director  \
# 0                      Drama     NaN    NaN       J.S. Randhawa
# 1                      Drama     7.0      8       Gaurav Bakshi
# 2             Drama, Musical     NaN    NaN  Soumyajit Majumdar
# 3            Comedy, Romance     4.4     35          Ovais Khan
# ...

# %%
data.tail()
# Out:
#                       Name    Year Duration          Genre  Rating Votes  \
# 15504  Zulm Ko Jala Doonga  (1988)      NaN         Action     4.6    11
# 15505                Zulmi  (1999)  129 min  Action, Drama     4.5   655
# 15506            Zulmi Raj  (2005)      NaN         Action     NaN   NaN
# 15507        Zulmi Shikari  (1988)      NaN         Action     NaN   NaN
# 15508         Zulm-O-Sitam  (1998)  130 min  Action, Drama     6.2    20
#
#             Director           Actor 1         Actor 2        Actor 3
# 15504  Mahendra Shah  Naseeruddin Shah   Sumeet Saigal  Suparna Anand
# 15505     Kuku Kohli      Akshay Kumar  Twinkle Khanna    Aruna Irani
# 15506     Kiran Thej   Sangeeta Tiwari             NaN            NaN
# 15507            NaN               NaN             NaN            NaN
# 15508   K.C. Bokadia        Dharmendra      Jaya Prada    Arjun Sarja

# %% [markdown]
# Find shape of our dataset

# %%
data.shape
# Out:
# (15509, 10)

# %%
print("Number of Rows", data.shape[0])
print("Number of Columns", data.shape[1])
# Out:
# Number of Rows 15509
# Number of Columns 10

# %% [markdown]
# Information about dataset

# %%
data.info
# Out:
# <bound method DataFrame.info of                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %% [markdown]
# Checking missing value in dataset

# %%
data.isnull()
# Out:
#         Name   Year  Duration  Genre  Rating  Votes  Director  Actor 1  \
# 0      False   True      True  False    True   True     False    False
# 1      False  False     False  False   False  False     False    False
# 2      False  False     False  False    True   True     False    False
# 3      False  False     False  False   False  False     False    False
# 4      False  False     False  False    True   True     False    False
# ...      ...    ...       ...    ...     ...    ...       ...      ...
# 15504  False  False      True  False   False  False     False    False
# 15505  False  False     False  False   False  False     False    False
# 15506  False  False      True  False    True   True     False    False
# 15507  False  False      True  False    True   True      True     True
# 15508  False  False     False  False   False  False     False    False
#
#        Actor 2  Actor 3
# 0        False    False
# 1        False    False
# 2        False    False
# ...

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
per_missing= data.isnull().sum()*100/len(data)
per_missing
# Out:
# Name         0.000000
# Year         3.404475
# Duration    53.317429
# Genre       12.102650
# Rating      48.939326
# Votes       48.932878
# Director     3.385131
# Actor 1     10.426204
# Actor 2     15.371720
# Actor 3     20.272100
# dtype: float64

# %% [markdown]
# Drop all missing values

# %%
data.dropna(axis=0)
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                                 #Yaaram  (2019)  110 min
# 5                    ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                               ...Yahaan  (2005)  142 min
# 8                      ?: A Question Mark  (2012)   82 min
# ...                                   ...     ...      ...
# 15493                              Zubaan  (2015)  115 min
# 15494                            Zubeidaa  (2001)  153 min
# 15503                     Zulm Ki Zanjeer  (1989)  125 min
# 15505                               Zulmi  (1999)  129 min
# 15508                        Zulm-O-Sitam  (1998)  130 min
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# ...

# %%
Check for duplicate values

# %%
dup_data = data.duplicated().any()  # Change 'duplicates' to 'duplicated'

# %%
data.drop_duplicates()
data.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %% [markdown]
# Overall statistics about dataframe

# %%
data.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %% [markdown]
# Highest average voting

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
data.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# (2012)    8257.154762
# (2007)    5839.558621
# (2016)    5786.945813
# (2020)    4884.491018
# (2013)    4588.609375
#              ...
# (1924)            NaN
# (1926)            NaN
# (1928)            NaN
# (1930)            NaN
# (2022)            NaN
# Name: Votes, Length: 102, dtype: float64

# %%
sns.barplot(x='Year', y='Votes', data=data)
plt.title('Highest average voting')
plt.show()

# %% [markdown]
# Average highest rating

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
data.groupby('Year')['Rating'].mean().sort_values(ascending=False)
# Out:
# Year
# (1948)    7.073684
# (1950)    7.061290
# (1940)    6.954545
# (1952)    6.848148
# (1953)    6.820690
#             ...
# (1924)         NaN
# (1926)         NaN
# (1928)         NaN
# (1930)         NaN
# (2022)         NaN
# Name: Rating, Length: 102, dtype: float64

# %%
sns.barplot(x='Year', y='Rating', data=data)
plt.title('Highest average voting')
plt.show()

# %% [markdown]
# Average rating for each director

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Saif Ali Sayeed    10.0
# Sriram Raja         9.7
# Bobby Kumar         9.6
# Arvind Pratap       9.4
# Ashish Dubey        9.4
#                    ...
# Zia Khan Lodhi      NaN
# Zia-ur-Rasheed      NaN
# Zohra               NaN
# Zubeida             NaN
# Zul Vellani         NaN
# Name: Rating, Length: 5938, dtype: float64

# %%
# Convert 'Duration' column to numeric, handling non-numeric values
data['Duration'] = pd.to_numeric(data['Duration'], errors='coerce')

# Now you can apply nlargest, include 'Director' in the columns
top10_len = data.nlargest(10, 'Duration')[['Name', 'Duration', 'Director']].set_index('Director')

# %%
top10_len
# Out:
#                                                   Name  Duration
# Director
# J.S. Randhawa                                                NaN
# Gaurav Bakshi       #Gadhvi (He thought he was Gandhi)       NaN
# Soumyajit Majumdar                         #Homecoming       NaN
# Ovais Khan                                     #Yaaram       NaN
# Amol Palekar                         ...And Once Again       NaN
# Rahul Rawail                      ...Aur Pyaar Ho Gaya       NaN
# Shoojit Sircar                               ...Yahaan       NaN
# Anirban Datta                           .in for Motion       NaN
# Allyson Patel                       ?: A Question Mark       NaN
# Biju Bhaskar Nair                             @Andheri       NaN

# %%
sns.barplot(x='Director', y='Duration', data=top10_len)  # Use 'Duration' for y-axis
plt.title('Top 10 longest movies')
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# Number of movies per year

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
data['Duration'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
sns.countplot(x='Year', data=data)
plt.title('Number of movies per year')
plt.show()

# %% [markdown]
# Most popular movie title

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
data['Rating'].max()
# Out:
# 10.0

# %%
data[data['Rating'] == data['Rating'].max()]
# Out:
#                  Name    Year  Duration           Genre  Rating  Votes  \
# 8339  Love Qubool Hai  (2020)       NaN  Drama, Romance    10.0    5.0
#
#              Director    Actor 1         Actor 2              Actor 3
# 8339  Saif Ali Sayeed  Ahaan Jha  Mahesh Narayan  Rajasree Rajakumari

# %% [markdown]
# Top 10 highest rated movie titles and its directors

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
top10_len = data.nlargest(10, 'Rating')[['Name', 'Rating', 'Director']].set_index('Director')

# %%
top10_len
# Out:
#                                 Name  Rating
# Director
# Saif Ali Sayeed      Love Qubool Hai    10.0
# Sriram Raja               Half Songs     9.7
# Bobby Kumar                    Breed     9.6
# Munni Pankaj            Gho Gho Rani     9.4
# Suhrud Godbole                  June     9.4
# Ashish Dubey                Ram-Path     9.4
# Arvind Pratap    The Reluctant Crime     9.4
# Rahul Mallick           Ashok Vatika     9.3
# Vishwa Bhanu                Baikunth     9.3
# Venkatesh Bk             God of gods     9.3

# %%
sns.barplot(x='Rating', y=top10_len.index, data=top10_len,hue='Director')  # Pass the index of top10_len as the y-axis
plt.title('Top 10 highest rated movies')
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# Find average votes of movies year wise

# %%
data.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# (2012)    8257.154762
# (2007)    5839.558621
# (2016)    5786.945813
# (2020)    4884.491018
# (2013)    4588.609375
#              ...
# (1924)            NaN
# (1926)            NaN
# (1928)            NaN
# (1930)            NaN
# (2022)            NaN
# Name: Votes, Length: 102, dtype: float64

# %% [markdown]
# Effect of rating on votes

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
sns.scatterplot(x='Rating', y='Votes', data=data)
plt.title('Effect of rating on votes')
plt.show()

# %% [markdown]
# Classification of movies on ratings(Excellent, good and average)

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
def rating(rating):
    if rating >= 7.0:
        return 'Excellent'
    elif rating >= 6.0:
        return 'Good'
    else:
        return 'Average'

# %%
data['Rating_cat'] = data['Rating'].apply(rating)

# %%
data.head()
# Out:
#                                  Name    Year  Duration            Genre  \
# 0                                         NaN       NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)       NaN            Drama
# 2                         #Homecoming  (2021)       NaN   Drama, Musical
# 3                             #Yaaram  (2019)       NaN  Comedy, Romance
# 4                   ...And Once Again  (2010)       NaN            Drama
#
#    Rating  Votes            Director       Actor 1             Actor 2  \
# 0     NaN    NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0    8.0       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN    NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4   35.0          Ovais Khan       Prateik          Ishita Raj
# 4     NaN    NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3 Rating_cat
# 0  Rajendra Bhatia    Average
# 1    Arvind Jangid  Excellent
# ...

# %% [markdown]
# Count number of action movies

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Rating_cat'],
#       dtype='object')

# %%
data['Genre'].dtype
# Out:
# dtype('O')

# %%
# Handle missing values in the 'Genre' column before filtering
len(data[data['Genre'].fillna('').str.contains('Action', case=False)])
# Out:
# 3543

# %% [markdown]
# Find unique values from genre

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Rating_cat'],
#       dtype='object')

# %%
data['Genre']
# Out:
# 0                  Drama
# 1                  Drama
# 2         Drama, Musical
# 3        Comedy, Romance
# 4                  Drama
#               ...
# 15504             Action
# 15505      Action, Drama
# 15506             Action
# 15507             Action
# 15508      Action, Drama
# Name: Genre, Length: 15509, dtype: object

# %%
list1 = []
for value in data['Genre']:
    if isinstance(value, str):  # Check if the value is a string
        list1.append(value.split(','))
    else:
        list1.append([])  # Handle non-string values (e.g., NaN) by appending an empty list

# %% [markdown]
# Films of each genre made

# %%
one_d=[]
for i in list1:
  for j in i: # Iterate over elements in the sublist i
    one_d.append(j) # Append each element to one_d

# %%
one_d
# Out:
# ['Drama',
#  'Drama',
#  'Drama',
#  ' Musical',
#  'Comedy',
#  ' Romance',
#  'Drama',
#  'Comedy',
#  ' Drama',
#  ' Musical',
#  'Drama',
#  ' Romance',
#  ' War',
#  'Documentary',
#  'Horror',
#  ' Mystery',
#  ' Thriller',
#  'Action',
#  ' Crime',
#  ' Thriller',
#  'Drama',
#  'Horror',
#  'Horror',
#  ' Romance',
#  ' Thriller',
#  'Comedy',
#  ' Drama',
#  ' Romance',
#  'Thriller',
#  'Comedy',
#  ' Drama',
#  'Comedy',
#  ' Drama',
#  ' Fantasy',
#  'Comedy',
#  ' Drama',
#  ' Romance',
#  'Comedy',
#  ' Drama',
#  ' Family',
#  'Crime',
#  ' Drama',
#  ' Mystery',
#  'Horror',
#  ' Thriller',
#  'Biography',
#  'Documentary',
#  'Comedy',
#  ' Horror',
#  'Action',
#  'Drama',
#  'Drama',
#  ' Horror',
#  ' Mystery',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Action',
#  ' Thriller',
#  'Action',
#  'Drama',
#  ' History',
#  'Drama',
#  'Drama',
#  ' History',
#  ' Sport',
#  'Horror',
#  ' Mystery',
#  ' Romance',
#  'Horror',
#  ' Mystery',
#  'Drama',
#  ' Horror',
# ...

# %%
from collections import Counter # Fix the typo in the module name

# %%
Counter(one_d)
# Out:
# Counter({'Drama': 4517,
#          ' Musical': 424,
#          'Comedy': 1561,
#          ' Romance': 1687,
#          ' Drama': 2726,
#          ' War': 39,
#          'Documentary': 383,
#          'Horror': 403,
#          ' Mystery': 365,
#          ' Thriller': 927,
#          'Action': 3487,
#          ' Crime': 863,
#          'Thriller': 786,
#          ' Fantasy': 266,
#          ' Family': 782,
#          'Crime': 459,
#          'Biography': 155,
#          ' Horror': 121,
#          ' History': 178,
#          ' Sport': 59,
#          'Adventure': 252,
#          ' Sci-Fi': 48,
#          'War': 8,
#          'Sport': 11,
#          ' Comedy': 468,
#          ' Adventure': 289,
#          ' Biography': 53,
#          'Mystery': 148,
#          'Musical': 165,
#          ' Music': 74,
#          'Romance': 762,
#          'Family': 161,
#          'Fantasy': 192,
#          'Sci-Fi': 10,
#          'Animation': 125,
#          'Music': 16,
#          'History': 29,
# ...
